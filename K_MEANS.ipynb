# %% [markdown]
# <a href="https://colab.research.google.com/github/shri3911/AIML-1/blob/main/K_MEANS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X = np.array([
    [0.1, 0.2],
    [0.2, 0.3],
    [0.3, 0.4],
    [-1, -2],
    [-3, -4],
    [-4, -5]
])

# %%
X = np.array([
    [0.1, 0.2],
    [0.2, 0.3],
    [0.3, 0.4],
    [-1, -2],
    [-3, -4],
    [-4, -5]
])

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
print("Cluster labels:", labels)
print("Cluster centroids:\n", centroids)
# Out:
# Cluster labels: [0 0 0 0 1 1]
# Cluster centroids:
#  [[-0.1   -0.275]
#  [-3.5   -4.5  ]]

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', label='Data points')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.title("K-Means Clustering")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.grid(True)
plt.show()
